# %% [markdown]
# # 4_inference

# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import os

from sklearn.decomposition import PCA
#from WMSE import WMSE

import tensorflow as tf
import time
import json
import pandas as pd
import pickle
from pitchfuncs import WMSE
from pitchfuncs import InversePCA
from pitchfuncs import emulator

from dynesty import NestedSampler
import scipy 
import corner
from dynesty import utils as dyfunc

### inverse PCA layer
#from InversePCA import InversePCA 
### 

### 

### Comment following out if running from laptop:
os.environ["CUDA_VISIBLE_DEVICES"]="1"


physical_devices = tf.config.list_physical_devices("GPU") 
gpu0usage = (tf.config.experimental.get_memory_info("GPU:0")["current"])

print("Current GPU usage:\n"
     + " - GPU0: " + str(gpu0usage) + "B\n")
# Out:
# 2024-03-19 15:15:52.718471: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-19 15:15:52.718503: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-19 15:15:52.719462: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-19 15:15:52.724319: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-19 15:15:53.245882: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Current GPU usage:
#  - GPU0: 0B
# 2024-03-19 15:15:54.007039: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 18447 MB memory:  -> device: 0, name: NVIDIA RTX A4500, pci bus id: 0000:61:00.0, compute capability: 8.6

# %%
class ns():
    def __init__(self, priors, observed_vals, observed_unc, pitchfork):
        self.priors = priors
        self.obs_val = observed_vals
        self.obs_unc = observed_unc
        self.ndim = len(priors)
        self.pitchfork = pitchfork
    
    def ptform(self, u):

        x = np.array([self.priors[i].ppf(u[i])[0] for i in range(self.ndim)])
        return x
        
    
    def model(self, x):
        
        obs = self.pitchfork.predict(np.array([x]))
        return obs
    
    def logl(self, x): 
        m = self.model(x)
        ll = 0.0
        ll += scipy.stats.norm.logpdf(m, loc = self.obs_val, scale = self.obs_unc)
        return np.sum(ll)
    
    def __call__(self, nlive=10):
        self.sampler = NestedSampler(self.logl, self.ptform, self.ndim, nlive=nlive,  
                                bound='multi', sample='rwalk')
        self.sampler.run_nested()
        self.results = self.sampler.results
        samples, weights = self.results.samples, np.exp(self.results.logwt - self.results.logz[-1])
        self.post_samples = dyfunc.resample_equal(samples, weights)
        
        return self.post_samples

# %%
"""
Load in grid
"""

df = pd.read_hdf('/home/oxs235/datastorage/repos_data/ojscutt/pitchfork/data/bob.h5', key='df') #change if accessing from RDS

# %%
pitchfork = emulator("nu6-40")
# Out:
# initial_mass range: [min = 0.8, max = 1.2]
# initial_Zinit range: [min = 0.003869061466818601, max = 0.0389797119014747]
# initial_Yinit range: [min = 0.24, max = 0.32]
# initial_MLT range: [min = 1.7, max = 2.5]
# star_age range: [min = 0.029664111540787196, max = 13.999973871651315]

# %%
"""
Define model point to use as makeshift observed star
"""
# For now, retrieve representative model point from the grid for hare
# Inrementally choose highest peak in histogram until we get to age, at which point just choose nice value (went for close to 4Gyr)
df_trim = df[df["initial_mass"] == 1.12]
df_trim = df_trim[df_trim["initial_Zinit"] == df_trim["initial_Zinit"].unique()[32]]
df_trim = df_trim[df_trim["initial_MLT"] == df_trim["initial_MLT"].unique()[1]]

model = df_trim[df_trim["star_age"] == df_trim["star_age"].iloc[(np.abs(df_trim["star_age"]-3)).argmin()]]

inputs = ['initial_mass', 'initial_Zinit', 'initial_Yinit', 'initial_MLT', 'star_age']
outputs = ['radius', 'luminosity', 'surface_Z'] + [f'nu_0_{i+1}' for i in range(5,40)]

model_inps = model[inputs]
model_outs = model[outputs]

model_outs
# Out:
#            radius  luminosity  surface_Z       nu_0_6       nu_0_7  \
# 6246893  0.984237    0.906909    0.02649  1051.318496  1210.399638
#
#               nu_0_8       nu_0_9     nu_0_10     nu_0_11      nu_0_12  ...  \
# 6246893  1368.520434  1526.091679  1680.80456  1833.31367  1982.616294  ...
#
#              nu_0_31      nu_0_32    nu_0_33      nu_0_34     nu_0_35  \
# 6246893  4778.107567  4926.706077  5075.3918  5223.891882  5372.01964
#
#              nu_0_36      nu_0_37      nu_0_38      nu_0_39      nu_0_40
# 6246893  5519.327075  5663.469649  5803.440344  5944.450225  6082.048799
#
# [1 rows x 38 columns]

# %%
"""
Define observed quantities and uncertainties
"""
obs = model_outs.values
unc = [0.1, 0.2, 0.001] + [0.4 for _ in range(5,40)]

# %%
"""
Define priors
"""
mass_prior = scipy.stats.uniform(loc=0.9*model_inps["initial_mass"], scale=1.1*model_inps["initial_mass"]-0.9*model_inps["initial_mass"])

Zinit_prior = scipy.stats.uniform(loc=0.9*model_inps["initial_Zinit"], scale=1.1*model_inps["initial_Zinit"]-0.9*model_inps["initial_Zinit"])

Yinit_prior = scipy.stats.uniform(loc=0.9*model_inps["initial_Yinit"], scale=1.1*model_inps["initial_Yinit"]-0.9*model_inps["initial_Yinit"])

MLT_prior = scipy.stats.uniform(loc=0.9*model_inps["initial_MLT"], scale=1.1*model_inps["initial_MLT"]-0.9*model_inps["initial_MLT"])

age_prior = scipy.stats.uniform(loc=0.9*model_inps["star_age"], scale=1.1*model_inps["star_age"]-0.9*model_inps["star_age"])

priors = [mass_prior,Zinit_prior, Yinit_prior, MLT_prior, age_prior]

# %%
sampler = ns(priors=priors, observed_vals=obs, observed_unc=unc,pitchfork=pitchfork)
posterior = sampler()

corner.corner(posterior)
plt.show()
# Out:
# 2024-03-19 15:16:04.917628: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-03-19 15:16:04.966179: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# iter: 2229 | bound: 0 | nc: 6 | ncall: 9194 | eff(%): 24.244 | loglstar:   -inf < -344088.813 <    inf | logz: -344098.642 +/-  0.099 | dlogz: 344391.847 >  1.009
# Exception while calling loglikelihood function:
#   params: [1.14634496 0.02524198 0.25059115 2.60733909 3.05597483]
#   args: []
#   kwargs: {}
#   exception:
# Traceback (most recent call last):
#   File "/home/oxs235/miniconda3/envs/pitchfork/lib/python3.9/site-packages/dynesty/dynesty.py", line 910, in __call__
#     return self.func(np.asarray(x).copy(), *self.args, **self.kwargs)
#   File "/tmp/ipykernel_570216/4002773005.py", line 21, in logl
#     m = self.model(x)
#   File "/tmp/ipykernel_570216/4002773005.py", line 17, in model
#     obs = self.pitchfork.predict(np.array([x]))
#   File "/home/oxs235/repos/ojscutt/sl-pitchfork/pitchfuncs.py", line 102, in predict
#     standardised_log_outputs = self.model.predict(standardised_log_inputs, verbose=verbose)
#   File "/home/oxs235/miniconda3/envs/pitchfork/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#     return fn(*args, **kwargs)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 sampler = ns(priors=priors, observed_vals=obs, observed_unc=unc,pitchfork=pitchfork)
# ----> 2 posterior = sampler()
#       4 corner.corner(posterior)
#       5 plt.show()
#
# Cell In[2], line 29, in ns.__call__(self, nlive)
#      26 def __call__(self, nlive=1000):
#      27     self.sampler = NestedSampler(self.logl, self.ptform, self.ndim, nlive=nlive,
#      28                             bound='multi', sample='rwalk')
# ---> 29     self.sampler.run_nested()
#      30     self.results = self.sampler.results
#      31     samples, weights = self.results.samples, np.exp(self.results.logwt - self.results.logz[-1])
#
# File ~/miniconda3/envs/pitchfork/lib/python3.9/site-packages/dynesty/sampler.py:1017, in Sampler.run_nested(self, maxiter, maxcall, dlogz, logl_max, n_effective, add_live, print_progress, print_func, save_bounds, checkpoint_file, checkpoint_every, resume)
#    1015 try:
#    1016     ncall = self.ncall
# -> 1017     for it, results in enumerate(
#    1018             self.sample(maxiter=maxiter,
#    1019                         maxcall=maxcall,
#    1020                         dlogz=dlogz,
#    1021                         logl_max=logl_max,
#    1022                         save_bounds=save_bounds,
#    1023                         save_samples=True,
#    1024                         n_effective=n_effective,
#    1025                         resume=resume,
#    1026                         add_live=add_live)):
#    1027         ncall += results.nc
#    1029         # Print progress.
#
# File ~/miniconda3/envs/pitchfork/lib/python3.9/site-packages/dynesty/sampler.py:840, in Sampler.sample(self, maxiter, maxcall, dlogz, logl_max, n_effective, add_live, save_bounds, save_samples, resume)
#     835     old_blob = None
#     837 # Sample a new live point from within the likelihood constraint
#     838 # `logl > loglstar` using the bounding distribution and sampling
#     839 # method from our sampler.
# --> 840 u, v, logl, nc = self._new_point(loglstar_new)
#     841 ncall += nc
#     842 self.ncall += nc
#
# File ~/miniconda3/envs/pitchfork/lib/python3.9/site-packages/dynesty/sampler.py:421, in Sampler._new_point(self, loglstar)
#     418 ncall_accum = 0
#     419 while True:
#     420     # Get the next point from the queue
# --> 421     u, v, logl, nc, blob = self._get_point_value(loglstar)
#     422     ncall += nc
#     423     ncall_accum += nc
#
# File ~/miniconda3/envs/pitchfork/lib/python3.9/site-packages/dynesty/sampler.py:404, in Sampler._get_point_value(self, loglstar)
#     402 # If the queue is empty, refill it.
#     403 if self.nqueue <= 0:
# --> 404     self._fill_queue(loglstar)
#     406 # Grab the earliest entry.
#     407 u, v, logl, nc, blob = self.queue.pop(0)
#
# File ~/miniconda3/envs/pitchfork/lib/python3.9/site-packages/dynesty/sampler.py:397, in Sampler._fill_queue(self, loglstar)
#     387 for i in range(self.queue_size):
#     388     args.append(
#     389         SamplerArgument(u=point_queue[i],
#     390                         loglstar=loglstar,
#    (...)
#     395                         rseed=seeds[i],
#     396                         kwargs=self.kwargs))
# --> 397 self.queue = list(mapper(evolve_point, args))
#
# File ~/miniconda3/envs/pitchfork/lib/python3.9/site-packages/dynesty/sampling.py:88, in sample_unif(args)
#      84 # Unzipping.
#      85
#      86 # Evaluate.
#      87 v = args.prior_transform(np.asarray(args.u))
# ---> 88 logl = args.loglikelihood(np.asarray(v))
#      89 nc = 1
#      90 blob = None
#
# File ~/miniconda3/envs/pitchfork/lib/python3.9/site-packages/dynesty/utils.py:187, in LogLikelihood.__call__(self, x)
#     183 def __call__(self, x):
#     184     """
#     185     Evaluate the likelihood f-n once
#     186     """
# --> 187     ret = LoglOutput(self.loglikelihood(x), self.blob)
#     188     if self.save:
#     189         self.history_append([ret.val], [x])
#
# File ~/miniconda3/envs/pitchfork/lib/python3.9/site-packages/dynesty/dynesty.py:910, in _function_wrapper.__call__(self, x)
#     902 def __call__(self, x):
#     903     try:
#     904         # IMPORTANT
#     905         # Here we make a copy if the input vector just to ensure
#    (...)
#     908         # This comes at performance cost, but it's worthwhile
#     909         # as it may lead to hard to diagnose weird behaviour
# --> 910         return self.func(np.asarray(x).copy(), *self.args, **self.kwargs)
#     911     except:  # noqa
#     912         print(f"Exception while calling {self.name} function:")
#
# Cell In[2], line 21, in ns.logl(self, x)
#      20 def logl(self, x):
# ---> 21     m = self.model(x)
#      22     ll = 0.0
#      23     ll += scipy.stats.norm.logpdf(m, loc = self.obs_val, scale = self.obs_unc)
#
# Cell In[2], line 17, in ns.model(self, x)
#      15 def model(self, x):
# ---> 17     obs = self.pitchfork.predict(np.array([x]))
#      18     return obs
#
# File ~/repos/ojscutt/sl-pitchfork/pitchfuncs.py:102, in emulator.predict(self, input_data, verbose)
#      98 log_inputs = np.log10(input_data)
#     100 standardised_log_inputs = (log_inputs - log_inputs_mean)/log_inputs_std
# --> 102 standardised_log_outputs = self.model.predict(standardised_log_inputs, verbose=verbose)
#     104 standardised_log_outputs = np.concatenate((np.array(standardised_log_outputs[0]),np.array(standardised_log_outputs[1])), axis=1)
#     106 log_outputs = (standardised_log_outputs*log_outputs_std) + log_outputs_mean
#
# File ~/miniconda3/envs/pitchfork/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# KeyboardInterrupt:

# %%
model_inps
# Out:
#          initial_mass  initial_Zinit  initial_Yinit  initial_MLT  star_age
# 6246893          1.12        0.02649           0.24          2.5  3.013309

# %%
inputs = ["initial_mass", "initial_Zinit", "initial_Yinit", "initial_MLT", "star_age"]

df_posterior = pd.DataFrame(posterior, columns=inputs)
corner.corner(df_posterior, range=[[1.1,1.15],[0.025,0.034],[0.238,0.26],[2.25,2.6],[1.7,3.1]],truths=model_inps.values.flatten().tolist());
#plt.savefig("figs/first_test_posteriors.png", transparent="false", facecolor="white")
plt.show()
# Out:
# WARNING:root:Too few points to create valid contours
